# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# # lets do EDA

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 97.6 KB

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %%
df.isnull().sum() # no null values
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df["HeartDisease"].value_counts().plot(kind = 'bar')  # Equaly Distributed
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
#lets check all data in graph

def ploating(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var], kde=True,)

# %%
ploating("Age",1)
ploating("MaxHR",2)
ploating("Cholesterol",3)
ploating("RestingBP",4)
plt.tight_layout()

# %%
# Cholesterol cant be 0 so we change or cleane
# same ReatingBP cant be 0 so we replace with mean

# %%
ch_mean = df.loc[df["Cholesterol"] != 0,"Cholesterol"].mean()
ch_mean.round(2)
# Out:
# np.float64(244.64)

# %%
df["Cholesterol"] = df["Cholesterol"].replace(0,ch_mean)

# %%
resting_bp = df.loc[df["RestingBP"] != 0, "RestingBP"].mean().round(2)

# %%
resting_bp
# Out:
# np.float64(132.54)

# %%
df["RestingBP"] = df["RestingBP"].replace(0,resting_bp)

# %%
ploating("Age",1)
ploating("MaxHR",2)
ploating("Cholesterol",3)
ploating("RestingBP",4)
plt.tight_layout()

# %%
# NOW DATA is Clean

# %%
pip install sheryanalysis
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sheryanalysis as sh

# %%
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# 📏 Shape: (918, 12)
# 🧱 Columns: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']
#
# ✅ No null values found
#
# 🔠 Categorical Columns: ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'HeartDisease']
#
# 🔢 Numerical Columns: ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
# {'shape': (918, 12),
#  'columns': ['Age',
#   'Sex',
#   'ChestPainType',
#   'RestingBP',
#   'Cholesterol',
#   'FastingBS',
#   'RestingECG',
#   'MaxHR',
#   'ExerciseAngina',
#   'Oldpeak',
#   'ST_Slope',
#   'HeartDisease'],
#  'dtypes': {'Age': dtype('int64'),
#   'Sex': <StringDtype(na_value=nan)>,
#   'ChestPainType': <StringDtype(na_value=nan)>,
#   'RestingBP': dtype('float64'),
#   'Cholesterol': dtype('float64'),
#   'FastingBS': dtype('int64'),
# ...

# %%
sns.countplot(x = df["Sex"],hue = df["HeartDisease"] )
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x = df["ChestPainType"], hue = df["HeartDisease"])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
col = ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
for c in col:
    plt.figure(figsize = (6,4))
    sns.countplot(x = df[c], hue = df["HeartDisease"])
