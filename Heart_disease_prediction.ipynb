# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  ...  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0   40   M           ATA        140          289  ...    172              N      0.0       Up             0
# 1   49   F           NAP        160          180  ...    156              N      1.0     Flat             1
# 2   37   M           ATA        130          283  ...     98              N      0.0       Up             0
# 3   48   F           ASY        138          214  ...    108              Y      1.5     Flat             1
# 4   54   M           NAP        150          195  ...    122              N      0.0       Up             0
#
# [5 rows x 12 columns]

# %% [markdown]
# # lets do EDA

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 97.6 KB

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %%
df.isnull().sum() # no null values
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df["HeartDisease"].value_counts().plot(kind = 'bar')  # Equaly Distributed
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
#lets check all data in graph

def ploating(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var], kde=True,)

# %%
ploating("Age",1)
ploating("MaxHR",2)
ploating("Cholesterol",3)
ploating("RestingBP",4)
plt.tight_layout()

# %%
# Cholesterol cant be 0 so we change or cleane
# same ReatingBP cant be 0 so we replace with mean

# %%
ch_mean = df.loc[df["Cholesterol"] != 0,"Cholesterol"].mean()
ch_mean.round(2)
# Out:
# np.float64(244.64)

# %%
df["Cholesterol"] = df["Cholesterol"].replace(0,ch_mean)

# %%
resting_bp = df.loc[df["RestingBP"] != 0, "RestingBP"].mean().round(2)

# %%
resting_bp
# Out:
# np.float64(132.54)

# %%
df["RestingBP"] = df["RestingBP"].replace(0,resting_bp)

# %%
ploating("Age",1)
ploating("MaxHR",2)
ploating("Cholesterol",3)
ploating("RestingBP",4)
plt.tight_layout()

# %%
# NOW DATA is Clean

# %%
import sheryanalysis as sh

# %%
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# 📏 Shape: (918, 12)
# 🧱 Columns: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']
#
# ✅ No null values found
#
# 🔠 Categorical Columns: ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'HeartDisease']
#
# 🔢 Numerical Columns: ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
# {'shape': (918, 12),
#  'columns': ['Age',
#   'Sex',
#   'ChestPainType',
#   'RestingBP',
#   'Cholesterol',
#   'FastingBS',
#   'RestingECG',
#   'MaxHR',
#   'ExerciseAngina',
#   'Oldpeak',
#   'ST_Slope',
#   'HeartDisease'],
#  'dtypes': {'Age': dtype('int64'),
#   'Sex': <StringDtype(na_value=nan)>,
#   'ChestPainType': <StringDtype(na_value=nan)>,
#   'RestingBP': dtype('float64'),
#   'Cholesterol': dtype('float64'),
#   'FastingBS': dtype('int64'),
# ...

# %%
sns.countplot(x = df["Sex"],hue = df["HeartDisease"] )
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x = df["ChestPainType"], hue = df["HeartDisease"])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
col = ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
for c in col:
    plt.figure(figsize = (6,4))
    sns.countplot(x = df[c], hue = df["HeartDisease"])

# %%
plt.figure(figsize = (8,6))
sns.heatmap(df.corr(numeric_only= True), annot= True)
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing and Cleaning

# %%
df_encoding = pd.get_dummies(df,drop_first= True)
df_encoding = df_encoding.astype(int)
df_encoding.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  ...  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  ST_Slope_Up
# 0   40        140          289          0  ...              0                 0              0            1
# 1   49        160          180          0  ...              0                 0              1            0
# 2   37        130          283          0  ...              1                 0              0            1
# 3   48        138          214          0  ...              0                 1              1            0
# 4   54        150          195          0  ...              0                 0              0            1
#
# [5 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
num_col = ["Age","RestingBP","Cholesterol","MaxHR","Oldpeak"]
df_encoding[num_col] = scaler.fit_transform(df_encoding[num_col])
df_encoding.head()
# Out:
#         Age  RestingBP  Cholesterol  FastingBS  ...  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  ST_Slope_Up
# 0 -1.433140   0.414885     0.834754          0  ...              0                 0              0            1
# 1 -0.478484   1.527224    -1.210675          0  ...              0                 0              1            0
# 2 -1.751359  -0.141284     0.722161          0  ...              1                 0              0            1
# 3 -0.584556   0.303651    -0.572651          0  ...              0                 1              1            0
# 4  0.051881   0.971054    -0.929194          0  ...              0                 0              0            1
#
# [5 rows x 16 columns]

# %%
X = df_encoding.drop("HeartDisease",axis = 1)
y = df_encoding["HeartDisease"]

# %%
X
# Out:
#           Age  RestingBP  Cholesterol  FastingBS  ...  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  ST_Slope_Up
# 0   -1.433140   0.414885     0.834754          0  ...              0                 0              0            1
# 1   -0.478484   1.527224    -1.210675          0  ...              0                 0              1            0
# 2   -1.751359  -0.141284     0.722161          0  ...              1                 0              0            1
# 3   -0.584556   0.303651    -0.572651          0  ...              0                 1              1            0
# 4    0.051881   0.971054    -0.929194          0  ...              0                 0              0            1
# ..        ...        ...          ...        ...  ...            ...               ...            ...          ...
# 913 -0.902775  -1.253622     0.365619          0  ...              0                 0              1            0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_knn = scaler.fit_transform(X_train)
X_test_knn = scaler.fit_transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier()

# %%
model_knn.fit(X_train_knn,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_prep_knn = model_knn.predict(X_test_knn)

# %%
y_test
# Out:
# 668    0
# 30     1
# 377    1
# 535    1
# 807    0
#       ..
# 211    1
# 745    1
# 584    1
# 878    0
# 451    1
# Name: HeartDisease, Length: 184, dtype: int64

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,y_prep_knn)
# Out:
# 0.8641304347826086

# %%
confusion_matrix(y_test,y_prep_knn)
# Out:
# array([[66, 11],
#        [14, 93]])

# %%
print(classification_report(y_test,y_prep_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84        77
#            1       0.89      0.87      0.88       107
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.86      0.86       184
# weighted avg       0.87      0.86      0.86       184

# %% [markdown]
# # Good Prediction in KNN Model

# %%
model_knn.fit(X_train_knn, y_train)
# Out:
# KNeighborsClassifier()

# %%
import joblib
joblib.dump(model_knn,"heartprediction.pkl")
# Out:
# ['heartprediction.pkl']

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
